# %%
# %run AI_driven_Financial_ChatBot.py
# Out:
# -------------------------------------------------------------------
#
# Enter 'Hi' to start the chatbot session; type 'exit' to quit: hi
#
# Hello! Welcome to the AI-driven Financial Chatbot!!!
#
# I can help you with your financial queries.
# Please select the company
# 1. Apple,
# 2. Microsoft,
# 3. Tesla
# Enter company name: apple
# Please select the year
# 1. 2023,
# 2. 2022,
# 3. 2021: 2023
#
# Please enter your query (e.g.,
# 1. 'revenue growth,%',
# 2. 'net income growth,%',
# 3. 'assets growth,%',
# 4. 'liabilities growth,%',
# 5. 'cash flow from operations,%',
# 6. 'total revenue',
# 7. 'net income',
# 8. 'total assets',
# 9. 'total liabilities',
# 10. 'cash flow from operations'): revenue growth,%
# The revenue growth for Apple was -1.45%.
#
# Do you have another query for the same company and year? (yes/no): yes
#
# Please enter your query (e.g.,
# 1. 'revenue growth,%',
# 2. 'net income growth,%',
# 3. 'assets growth,%',
# 4. 'liabilities growth,%',
# ...

# %%
# %run AI_driven_Financial_ChatBot.py
# Out:
# -------------------------------------------------------------------
#
# Enter 'Hi' to start the chatbot session; type 'exit' to quit: hi
#
# Hello! Welcome to the AI-driven Financial Chatbot!!!
#
# I can help you with your financial queries.
# Please select the company
# 1. Apple,
# 2. Microsoft,
# 3. Tesla
# Enter company name: Microsoft
# Please select the year
# 1. 2023,
# 2. 2022,
# 3. 2021: 2021
#
# Please enter your query (e.g.,
# 1. 'revenue growth,%',
# 2. 'net income growth,%',
# 3. 'assets growth,%',
# 4. 'liabilities growth,%',
# 5. 'cash flow from operations,%',
# 6. 'total revenue',
# 7. 'net income',
# 8. 'total assets',
# 9. 'total liabilities',
# 10. 'cash flow from operations'): liabilities growth,%
# The liabilities growth for Microsoft was -2.3%.
#
# Do you have another query for the same company and year? (yes/no): no
# -------------------------------------------------------------------
#
# Enter 'Hi' to start the chatbot session; type 'exit' to quit: hi
#
# ...

# %%
# %run AI_driven_Financial_ChatBot.py
# Out:
# -------------------------------------------------------------------
#
# Enter 'Hi' to start the chatbot session; type 'exit' to quit: hi
#
# Hello! Welcome to the AI-driven Financial Chatbot!!!
#
# I can help you with your financial queries.
# Please select the company
# 1. Apple,
# 2. Microsoft,
# 3. Tesla
# Enter company name: Tesla
# Please select the year
# 1. 2023,
# 2. 2022,
# 3. 2021: 2022
#
# Please enter your query (e.g.,
# 1. 'revenue growth,%',
# 2. 'net income growth,%',
# 3. 'assets growth,%',
# 4. 'liabilities growth,%',
# 5. 'cash flow from operations,%',
# 6. 'total revenue',
# 7. 'net income',
# 8. 'total assets',
# 9. 'total liabilities',
# 10. 'cash flow from operations'): net income
# The net income for Tesla in 2022 was 12556.
#
# Do you have another query for the same company and year? (yes/no): yes
#
# Please enter your query (e.g.,
# 1. 'revenue growth,%',
# 2. 'net income growth,%',
# 3. 'assets growth,%',
# 4. 'liabilities growth,%',
# ...
